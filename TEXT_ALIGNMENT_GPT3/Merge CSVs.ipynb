# %% [markdown]
# # Merge Multiple CSVs
# ## Goal
# - Merge multiple CSV in one

# %% [markdown]
# # Imports and Preprocess

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from os import listdir
from os.path import isfile, join

# %%
mypath = "drive/MyDrive/Courses/Semester1/NLP/Project/Data/GPT3/CurrItr4/"
csv_files = []
count = 0
for f in listdir(mypath):
    if isfile(join(mypath, f)):
        count += 1
        csv_files.append(f)
        # print(f)

print("File Count: ", count)
# Out:
# File Count:  65

# %%
df = pd.DataFrame()

for file in csv_files:
    # print("Filename: ", file)
    df_temp = pd.read_csv(mypath + "/" + file)
    df = df.append(df_temp, ignore_index=True)
# df
print("Total Rows: ", len(df))
# Out:
# Total Rows:  2812

# %%
df
# Out:
#                                                    CODE  \
# 0     #!/usr/sbin/setkey -f\n#\n# SPD for gateway A ...
# 1       string    signature format identifier (as sp...
# 2     HTTP/1.1 200 OK\nContent-type: text/html\nSet-...
# 3     @ setlocal enableextensions \n@ cd /d "%~dp0"\...
# 4     [Client] <=========================> [Proxy] <...
# ...                                                 ...
# 2807  0: kd> ?? (char *)@$proc->ImageFileName\nchar ...
# 2808  int main() {\n  int a[10];\n  a[4] = 4;\n}\n\n...
# 2809  addr_set = currentProgram.getMemory()\nf = Fil...
# 2810  cd filesystem/\ncp $(which qemu-mips-static) ....
# 2811  tui enable\ntui new-layout mylayout {-horizont...
#
#                                                    TEXT ENTAILMENT
# 0     I found a question and answer related to keys ...       True
# 1     Found the answer myself in : Signatures are en...       True
# 2     Answer 1: if the server uses SSL/HTTPS(verifie...       True
# ...

# %%
# Creating csv for the mains
path_main = "drive/MyDrive/Courses/Semester1/NLP/Project/Data/GPT3/Prev/"

# %%
df.to_csv(path_main + 'Curr4-0.8-10-Prompt.csv', mode='w', index=False, header=True)
